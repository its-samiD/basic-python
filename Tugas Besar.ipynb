# %%
import math
import datetime 
x = datetime.datetime.now()
import os
import random
default = "maaf, aku belum bisa/tidak dapat memprosesnya"

# %%
print('halo perkenalkan aku AIs, Asisten Virtual Pertamamu')
print('siapa namamu?')
# Out:
# halo perkenalkan aku AIs, Asisten Virtual Pertamamu
# siapa namamu?

# %%
nama=input(' masukkan nama kamu')

print('salam kenal {}'.format(nama))
# Out:
#  masukkan nama kamu dimas
# salam kenal  dimas

# %%
print('---menu---')
print('1. Kalkulator')
print('2. Agenda')
print('3. Bot chat')
# Out:
# ---menu---
# 1. Kalkulator
# 2. Agenda
# 3. Bot chat

# %%
opsi_menu=input('')
# Out:
# 2

# %%
import datetime
x = datetime.datetime.now()
while True:
    if(opsi_menu)=="1":
        print("--- pilihlah opsi operasi matematika berikut ---- ")
        print('1. biasa')
        print('2. rumus cepat')
        print('999. keluar')
        opsi_calc=input('pilihlah opsi')
        print('kamu memilih opsi {}'.format(opsi_calc))
        if (opsi_calc)=="1":
            print('--- pilihlah opsi berikut---')
            print('1. pertambahan')
            print('2. pengurangan')
            print('3. perkalian')
            print('4. pembagian')
            print('5. pangkat')
            opsi_biasa=input('pilihlah opsi')
            print('kamu memilih opsi {}'.format(opsi_biasa))
            if(opsi_biasa)=='1': ##penambahan
                angka1=float(input('masukkan angka'))
                angka2=float(input('masukkan angka'))
                penambahan=angka1 + angka2
                print(penambahan)
            elif(opsi_biasa)=='2': ##pengurangan
                print('notes : angka pertama dikurang angka kedua')
                angka1=float(input('masukkan angka'))
                angka2=float(input('masukkan angka'))
                pengurangan=angka1 - angka2
                print(pengurangan)
            elif(opsi_biasa)=='3': ##perkalian
                angka1=float(input("masukkan angka "))
                angka2=float(input('masukkan angka '))
                perkalian=angka1*angka2
                print(perkalian)
            elif(opsi_biasa)=='4':
                print('note : angka pertama dibagi angka ke 2')
                print(' ')
                angka1=float(input('masukkan angka'))
                angka2=float(input('masukkan angka'))
                pembagian=angka1/angka2
                print(pembagian)
            elif(opsi_biasa)=='5':##bilangan pangkat
                print('note: angka pertama dipangkat angka ke 2')
                angka1=float(input('masukkan angka'))
                angka2=float(input('dipangkat dengan '))
                pangkat=angka1**angka2
                print(pangkat)
            else:
                print(default)
        elif(opsi_calc)=='2':
            print('--- pilihlah opsi berikut---')
            print('1. hitung luas')
            print('2. keliling 2dimensi')
            print('3. hitung volume')
            opsi_rc=input(' pilihlah opsi ')
            if(opsi_rc)=='1':
                print('1. luas persegi')
                print('2. luas persegi panjang')
                print('3. luas segitiga')
                print('4. luas trapesium')
                print('5. luas lingkaran')
                opsi_luas=input('pilihlah opsi ')
                if(opsi_luas)=='1':
                    sisi=float(input('masukkan panjang sisi'))
                    luas=sisi*sisi
                    print(luas)
                elif(opsi_luas)=="2":
                    print('note : pastikan panjang dan lebar memiliki satuan yang sama')
                    p=float(input('masukkan panjang'))
                    l=float(input('masukkan lebar'))
                    luas=p*l
                    print(luas)
                elif(opsi_luas)=='3':
                    print('note : pastikan alas dan tinggi memiliki satuan yang sama')
                    a=float(input('masukkan panjang alas'))
                    t=float(input('masukkan tinggi'))
                    luas=a*t
                    print(luas)
                elif(opsi_luas)=='4':
                    print('note : pastikan semua memiliki satuan yang sama')
                    s1=float(input('masukkan panjang sisi sejajar 1'))
                    s2=float(input('masukkan panjang sisi sejajar 2'))
                    s=s1+s2
                    t=float(input('masukkan tinggi'))
                    luas= 0.5*s*t
                    print(luas)
                elif(opsi_luas)=='5':
                    r=float(input('masukkan jari-jari'))
                    phi=math.pi
                    luas=phi*r*r
                    print(luas)
                else:
                    print(default)
            elif(opsi_rc)=='2':
                print('--pilihlah opsi berikut ---')
                print('1. persegi')
                print('2. persegi panjang')
                print('3. lingkaran')
                print('4. segitiga sama sisi')
                print('5. segitiga tidak sama sisi')
                opsi_k=input('pilih opsi ')
                if(opsi_k)=='1':
                    s=float(input('masukkan sisi'))
                    kliling=4*s
                    print(kliling)
                elif(opsi_k)=='2':
                    p=float(input('masukkan panjang'))
                    l=float(input('masukkan lebar'))
                    kliling=4*(p+l)
                    print(kliling)
                elif(opsi_k)=='3':
                    r=float(input('masukkan jari-jari'))
                    pi=math.pi
                    kliling=2*pi*r
                    print(kliling)
                elif(opsi_k)=='4':
                    sisi=float(input('masukkan panjang sisi'))
                    kliling=sisi*3
                    print(kliling)
                elif(opsi_k)=='5':
                    sisi1=float(input('masukkan panjang sisi 1'))
                    sisi2=float(input('masukkan panjang sisi 2'))
                    sisi3=float(input('masukkan panjang sisi 3'))
                    kliling=sisi1+sisi2+sisi3
                    print(kliling)
                else:
                    print(default)
            elif(opsi_rc)=='3':
                print('--- pilihlah opsi berikut ----')
                print('1. volume prisma')
                print('2. volume limas')
                print('3. volume bola')
                opsi_v=input('pilihlah opsi ')
                if(opsi_v)=='1':
                    print('- pilihlah opsi berikut -')
                    print('1. prisma segitiga')
                    print('2. prisma segiempat')
                    print('3. prisma lingkaran /tabung')
                    opsi_p=input('pilihlah opsi')
                    if(opsi_p)=='1':
                        a=float(input('masukkan panjang alas'))
                        t=float(input('masukkan tinggi segitiga'))
                        T=float(input('masukkan tinggi prisma'))
                        volume=a*t*T
                        print(volume)
                    elif(opsi_p)=='2':
                        s1=float(input('masukkan panjang sisi 1'))
                        s2=float(input('masukkan panjang sisi 2'))
                        t=float(input('masukkan tinggi'))
                        volume=s1*s2*t
                        print(volume)
                    elif(opsi_p)=='3':
                        pi=math.pi
                        r=float(input('masukkan jari-jari'))
                        t=float(input('masukkan tinggi'))
                        volume=pi*r*r*t
                        print(volume)
                        print(' ')
                    else:
                        print(default)
                elif(opsi_v)=='2':
                    print('- pilihlah opsi berikut -')
                    print('1. limas segitiga')
                    print('2. limas segiempat')
                    print('3. limas lingkaran')
                    opsi_l=input('pilihlah opsi ')
                    koef_limas=1/3
                    if (opsi_l)=='1':
                        a=float(input('masukkan panjang alas '))
                        b=float(input('masukkan tinggi segitiga '))
                        c=float(input('masukkan tinggi limas'))
                        luas= koef_limas * 0.5*a*b*c
                        print(luas)
                        print(' ')
                    elif(opsi_l)=='2':
                        a=float(input('masukkan panjang'))
                        b=float(input('masukkan lebar'))
                        c=float(input('masukkan tinggi'))
                        luas=koef_limas*a*b*c
                        print(luas)
                        print(' ')
                    elif(opsi_l)=='3':
                        a=float(input('masukkan jari-jari'))
                        pi=math.pi
                        b=float(input('masukkan tinggi'))
                        luas=koef_limas*a*a*b*pi
                        print(luas)
                        print(' ')
                    else:
                        print(default)
                elif(opsi_v)=='3':
                    koef_bola=4/3
                    pi=math.pi
                    a=float(input('masukkan jari-jari bola'))
                    volume=koef_bola*pi*a*a*a
                    print(volume)
                    print(' ')
                    
                else:
                    print(default)
        elif(opsi_calc)=='999':
            break
    elif(opsi_menu)=='2':
        print('pilih opsi')
        print('1. catat')
        print('2. simpan')
        print('3. keluar')
        agenda=input('pilihan {} '.format(nama))
        while True:
            if(agenda)=='1':
                xtu=input('masukkan catatan mu')
                u=( '{} mencatat {}'.format(nama,xtu))
                print(u)
            elif(agenda)=='3':
                break
            else:
                print(default)
                break
    else:
        print(default)
        break

# %%
print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', 'agenda.txt', 'basic-python', 'maths-0.0.0-py3.7.egg', 'maths-0.0.0.tar.gz', 'pertemuan1.ipynb', 'Pertemuan2.ipynb', 'README.md', 'Tugas minggu 1.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb']

# %% [markdown]
# ##
